# %%
import numpy as np
import matplotlib.pyplot as pl
import pandas as pd
import csv
from collections import defaultdict, Counter
# %matplotlib notebook

# %%
 color_feb=['#023858','#9ECAE1','#FEB24C','#BCBDDC','#9E9AC8','#807DBA','#6BAED6',
            '#D8BFD8','#BDBDBD','#4292C6','#2171B5','#08519C','#6A51A3','#969696',
            '#FF00FF','#54278F','#3F007D','#737373','#08306B','#FCC5C0','#525252',
            '#FD8D3C','#808080','#FA9FB5','#F768A1','#FC4E2A','#FDAE6B','#B8B8B8',
            '#DCDCDC','#D3D3D3','#C0C0C0','#DD3497','#AE017E','#696969','#8C6BB1',
            '#8C96C6','#778899','#708090','#FD8D3C','#F16913','#88419D','#D94801',
            '#A63603','#7F2704','#FEC44F','#810F7C']
color_apr=['#023858','#9ECAE1','#FEB24C','#6BAED6','#FD8D3C','#BDBDBD','#D8BFD8',
           '#FF00FF','#FC4E2A','#FDAE6B','#FCC5C0','#FA9FB5','#BCBDDC','#4292C6',
           '#2171B5','#FD8D3C','#F16913','#F768A1','#08519C','#969696','#DD3497',
           '#08306B','#9E9AC8','#807DBA','#74A9CF','#3690C0','#0570B0','#AE017E',
           '#FA9FB5','#F768A1','#737373','#525252','#808080','#D94801','#A63603',
           '#B8B8B8','#DCDCDC','#D3D3D3','#C0C0C0','#6A51A3','#045A8D','#696969',
           '#7F2704','#778899','#70809z','#2F4F4F','#A6BDDB','#546161','#F0F0F0',
           '#54278F','#3F007D','#8C6BB1','#FEC44F','#4682B4','#D0D1E6','#8C96C6',
           '#88419D','#FE9929','#D9D9D9','#F5F5F5','#EC7014','#DD3497','#CC4C02',
           '#252525','#993404','#810F7C','#88419D','#C6DBEF','#662506']

# %%
def Distribution(Gdis):
   
    n = []
    mj = np.unique(Gdis)
    for ii in mj:
        n.append(len(np.where(Gdis>=(ii))[0]))
    y = [(n[t]/n[0]) for t in range(len(n))]
        
    return mj,y,n

# %%
a0,a1,a2,a3,a4=[],[],[],[],[]
h= 0
with open('communities_degrees_Feb23-29.csv', newline = '') as players_data: #communities_degrees_Feb23-29 Apr05-11
    game_reader = csv.reader(players_data, delimiter=',')
    for game in game_reader:
        if h==0: print(game)
        if h>1:
            a0.append(game[0])
            a1.append(int(game[1]))
            a2.append(int(game[2]))
            a3.append(float(game[3]))
            a4.append(float(game[4]))
        h += 1
# Out:
# ['node_id', 'cluster', 'degree', 'lat', 'long']

# %%
df = pd.DataFrame({'a':a1, 'b':a2})
m_s = df.groupby('a')['b'].apply(list)

# %%
r= 0
fig = pl.figure(figsize=(5.3,5))
for i in m_s:
    xk,yk,nk = Distribution(np.array(i))
    pl.plot(xk, nk,'*',color=color_feb[r],linewidth= 3,markersize=2)
    r+=1
pl.xlabel('Degree',fontsize=20)
pl.ylabel('Nodes',fontsize=20)
pl.xscale('log')
pl.yscale('log')
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)
pl.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="530">

# %%
with open('communities_degrees_Feb23-29.csv', newline = '') as players_data: #communities_degrees_Feb23-29 Apr05-11
    game_reader = csv.reader(players_data, delimiter=',')
    for game in game_reader:
        if h==0: print(game)
        break
